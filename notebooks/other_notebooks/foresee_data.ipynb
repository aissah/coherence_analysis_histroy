# %%
import dascore as dc
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.insert(1, 'D:\CSM\Mines_Research\tdms_reader.py_')
# from tdms_reader import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 7
#       5 import sys
#       6 sys.path.insert(1, 'D:\CSM\Mines_Research\tdms_reader.py_')
# ----> 7 from tdms_reader import *
#
# ModuleNotFoundError: No module named 'tdms_reader'

# %%
directory = 'D:\CSM\Mines_Research\Test_data\FORESEE_Aug'
spool = dc.spool(directory)

contents = spool.get_contents()
print(contents)
# Out:
#   data_category          dims                      time_min data_type  \
# 0                channel,time 2019-08-01 00:00:04.511000064
# 1                channel,time 2019-08-01 00:10:04.511000064
# 2                channel,time 2019-08-01 00:20:04.511000064
# 3                channel,time 2019-08-01 00:30:04.511000064
# 4                channel,time 2019-08-01 00:40:04.511000064
# 5                channel,time 2019-08-01 00:50:04.511000064
# 6                channel,time 2019-08-01 01:00:04.511000064
# 7                channel,time 2019-08-01 01:10:04.511000064
# 8                channel,time 2019-08-01 01:20:04.511000064
# 9                channel,time 2019-08-01 01:30:04.511000064
#
#   experiment_id file_version station                      time_max  \
# 0                          1         2019-08-01 00:10:04.503000064
# 1                          1         2019-08-01 00:20:04.503000064
# 2                          1         2019-08-01 00:30:04.503000064
# 3                          1         2019-08-01 00:40:04.503000064
# 4                          1         2019-08-01 00:50:04.503000064
# 5                          1         2019-08-01 01:00:04.503000064
# 6                          1         2019-08-01 01:10:04.503000064
# 7                          1         2019-08-01 01:20:04.503000064
# 8                          1         2019-08-01 01:30:04.503000064
# 9                          1         2019-08-01 01:40:04.503000064
#
#                time_step                              path network tag  \
# 0 0 days 00:00:00.008000  FORESEE_UTC_20190801_000004.hdf5
# 1 0 days 00:00:00.008000  FORESEE_UTC_20190801_001004.hdf5
# 2 0 days 00:00:00.008000  FORESEE_UTC_20190801_002004.hdf5
# 3 0 days 00:00:00.008000  FORESEE_UTC_20190801_003004.hdf5
# 4 0 days 00:00:00.008000  FORESEE_UTC_20190801_004004.hdf5
# 5 0 days 00:00:00.008000  FORESEE_UTC_20190801_005004.hdf5
# 6 0 days 00:00:00.008000  FORESEE_UTC_20190801_010004.hdf5
# 7 0 days 00:00:00.008000  FORESEE_UTC_20190801_011004.hdf5
# 8 0 days 00:00:00.008000  FORESEE_UTC_20190801_012004.hdf5
# 9 0 days 00:00:00.008000  FORESEE_UTC_20190801_013004.hdf5
#
#   file_format instrument_id  _modified
# 0    H5Simple                    False
# 1    H5Simple                    False
# 2    H5Simple                    False
# 3    H5Simple                    False
# 4    H5Simple                    False
# 5    H5Simple                    False
# 6    H5Simple                    False
# 7    H5Simple                    False
# 8    H5Simple                    False
# 9    H5Simple                    False

# %%
patch = spool[6]
array = np.array(patch.data)
array.shape
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 patch = spool[6]
#       2 array = np.array(patch.data)
#       3 array.shape
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\core\spool.py:376, in DataFrameSpool.__getitem__(self, item)
#     370     out = self.new_from_df(
#     371         df=new_df,
#     372         instruction_df=new_inst,
#     373         source_df=new_source,
#     374     )
#     375 else:  # a single index was used, should return a single patch
# --> 376     out = self._unbox_patch(self._get_patches_from_index(item))
#     377 return out
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\core\spool.py:405, in DataFrameSpool._get_patches_from_index(self, df_ind)
#     403 assert not df1.empty
#     404 joined = df1.join(source.drop(columns=df1.columns, errors="ignore"))
# --> 405 return self._patch_from_instruction_df(joined)
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\core\spool.py:415, in DataFrameSpool._patch_from_instruction_df(self, joined)
#     412 for patch_kwargs in df_dict_list:
#     413     # convert kwargs to format understood by parser/patch.select
#     414     kwargs = _convert_min_max_in_kwargs(patch_kwargs, joined)
# --> 415     patch = self._load_patch(kwargs)
#     416     # If the limits of the source patch were not modified, we can just
#     417     # use the select kwargs. This is important for missing coordinates
#     418     # (NaN values) to not get trimmed out.
#     419     if kwargs.get("_modified"):
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\clients\dirspool.py:129, in DirectorySpool._load_patch(self, kwargs)
#     127 final_kwargs = dict(kwargs)
#     128 final_kwargs.update(self._select_kwargs)
# --> 129 patch = dc.read(**final_kwargs)[0]
#     130 return patch
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\io\core.py:632, in read(path, file_format, file_version, time, distance, **kwargs)
#     630 required_type = fiber_io.read._required_type
#     631 path = man.get_resource(required_type)
# --> 632 out = fiber_io.read(
#     633     path,
#     634     file_version=file_version,
#     635     time=time,
#     636     distance=distance,
#     637     _pre_cast=True,
#     638     **kwargs,
#     639 )
#     640 # if resource has a seek go back to 0 so this stream can be re-used.
#     641 getattr(path, "seek", lambda x: None)(0)
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\io\core.py:395, in _type_caster.<locals>._wrapper(_pre_cast, *args, **kwargs)
#     391 # TODO look at replacing this with pydantic's type_guard thing.
#     392
#     393 # this allows us to fast-track calls from generic functions
#     394 if required_type is None or _pre_cast:
# --> 395     return func(*args, **kwargs)
#     396 bound = sig.bind(*args, **kwargs)
#     397 new_kw = bound.arguments
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\io\h5simple\core.py:40, in H5Simple.read(self, resource, snap, **kwargs)
#      27 """
#      28 Read a simple h5 file.
#      29
#    (...)
#      37     Passed to filtering coordinates.
#      38 """
#      39 attrs, cm, data = _get_attrs_coords_and_data(resource, snap, self)
# ---> 40 new_cm, new_data = _maybe_trim_data(cm, data, kwargs)
#      41 patch = dc.Patch(coords=new_cm, data=new_data[:], attrs=attrs)
#      42 return dc.spool([patch])
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\io\h5simple\utils.py:22, in _maybe_trim_data(cm, data, kwargs)
#      20 def _maybe_trim_data(cm, data, kwargs):
#      21     """Maybe use kwargs to trim data array."""
# ---> 22     new_cm, new_data = cm.select(array=data, **kwargs)
#      23     return new_cm, new_data
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\core\coordmanager.py:603, in CoordManager.select(self, array, relative, samples, **kwargs)
#     599     new_coords, indexers = _get_indexers_and_new_coords_dict(
#     600         self, kwargs, samples=samples, relative=relative, operation="select"
#     601     )
#     602     self = self.update(**new_coords)
# --> 603     array = _apply_union_indexers(indexers, array)
#     604 return self, array
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\dascore\utils\misc.py:710, in _apply_union_indexers(indexer, array)
#     708         out = out[broadcast_for_index(ndim, axis, ind)]
#     709 else:
# --> 710     out = array[indexer]
#     711 return out
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\tables\array.py:650, in Array.__getitem__(self, key)
#     647 try:
#     648     # First, try with a regular selection
#     649     startl, stopl, stepl, shape = self._interpret_indexing(key)
# --> 650     arr = self._read_slice(startl, stopl, stepl, shape)
#     651 except TypeError:
#     652     # Then, try with a point-wise selection
#     653     try:
#
# File d:\CSM\Mines_Research\Repositories\Coherence_Analyses\.venv\Lib\site-packages\tables\array.py:754, in Array._read_slice(self, startl, stopl, stepl, shape)
#     747 def _read_slice(self,
#     748                 startl: np.ndarray,
#     749                 stopl: np.ndarray,
#     750                 stepl: np.ndarray,
#     751                 shape: list[int]) -> np.ndarray:
#     752     """Read a slice based on `startl`, `stopl` and `stepl`."""
# --> 754     nparr = np.empty(dtype=self.atom.dtype, shape=shape)
#     755     # Protection against reading empty arrays
#     756     if 0 not in shape:
#     757         # Arrays that have non-zero dimensionality
#
# MemoryError: Unable to allocate 306. MiB for an array with shape (2137, 75000) and data type float16

# %%
plt.figure(figsize=(10, 7))
plt.imshow(array[:,:7500], cmap='RdBu', aspect='auto', clim=(-10, 10), extent=[0, 60, 0, 4800])
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.colorbar()
